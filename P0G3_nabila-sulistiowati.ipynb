# %%
'''
=================================================
Graded Challenge 3

Nama  : Nabila Sulistiowati
Batch : CODA-RMT-003

Program ini dibuat untuk melakukan automatisasi pengolahan (cleaning) data text yang berguna untuk pemodelan model analisa sentimen.
=================================================
'''
# Out:
# '\n=================================================\nGraded Challenge 3\n\nNama  : Nabila Sulistiowati\nBatch : CODA-RMT-003\n\nProgram ini dibuat untuk melakukan automatisasi pengolahan (cleaning) data text yang berguna untuk pemodelan model analisa sentimen.\n=================================================\n'

# %%
# Import Library
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
# Out:
# /Users/bee/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Call webdriver
driver = webdriver.Safari()

# %%
url = "https://www.tokopedia.com/search?navsource=&page=1&q=seblak&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st="
driver.get(url) # Manggil data

# %%
html = driver.page_source # Akses url
soup = BeautifulSoup(html, "html.parser") # Mendapatkan datanya dalam bentuk HTML yang sudah dipisahkan
soup
# Out:
# <html data-rh="lang,translate" lang="id" translate="no"><head>
# <title>Jual seblak | Tokopedia</title>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1, minimum-scale=1, maximum-scale=5, user-scalable=yes, width=device-width" name="viewport"/>
# <link crossorigin="" href="https://assets.tokopedia.net" rel="preconnect"/><link href="https://assets.tokopedia.net" nonce="" rel="dns-prefetch"/>
# <link crossorigin="" href="https://gql.tokopedia.com" rel="preconnect"/><link href="https://gql.tokopedia.com" nonce="" rel="dns-prefetch"/>
# <link crossorigin="" href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" nonce="" rel="dns-prefetch"/>
# <link crossorigin="" href="https://www.google-analytics.com" rel="preconnect"/><link href="https://www.google-analytics.com" nonce="" rel="dns-prefetch"/>
# ...

# %%
# Nama produk
# <span class="_0T8-iGxMpV6NEsYEhwkqEg==">Seblak Instant Komplit Frozen</span>
# <div class="_6+OpBPVGAgqnmycna+bWIw=="><span class="_0T8-iGxMpV6NEsYEhwkqEg==">Seblak Instan Premium Bangsatria</span></div>

# Harga produk
# <div class="XvaCkHiisn2EZFq0THwVug=="><div class="_67d6E1xDKIzw+i2D2L0tjw== ">Rp20.000</div></div>
# <div class="XvaCkHiisn2EZFq0THwVug=="><div class="_67d6E1xDKIzw+i2D2L0tjw== ">Rp21.000</div></div>

# Penjual
# <span class="T0rpy-LEwYNQifsgB-3SQw== pC8DMVkBZGW7-egObcWMFQ== flip">Knads</span>
# <div class="Jh7geoVa-F3B5Hk8ORh2qw=="><span class="T0rpy-LEwYNQifsgB-3SQw== pC8DMVkBZGW7-egObcWMFQ== flip">Foodstocks</span><span class="pC8DMVkBZGW7-egObcWMFQ== flip">Jakarta Selatan</span></div>
# atau
# <span class="T0rpy-LEwYNQifsgB-3SQw== pC8DMVkBZGW7-egObcWMFQ== flip">Foodstocks</span>

# Kota Toko
# <span class="pC8DMVkBZGW7-egObcWMFQ== flip">Bekasi</span>
# <span class="pC8DMVkBZGW7-egObcWMFQ== flip">Jakarta Selatan</span>

# Banyaknya terjual
#  'SEBLAK KERUPUK BETON / KERUPUK JAAT CIKRUH PEDAS DAUN JERUK 100GR KHAS BANDUNG',
#  'Kerupuk krupuk Orange oren Seblak Ikan Udang Matahari Pagi MP mentah 250gr 250 gr gram']

# %%
# Akses harga
price = [harga.text for harga in soup.find_all("div", {"class":"XvaCkHiisn2EZFq0THwVug=="})]
price
# Out:
# ['Rp19.500',
#  'Rp12.500',
#  'Rp32.999',
#  'Rp14.200',
#  'Rp11.999',
#  'Rp55.600',
#  'Rp19.700Rp30.000',
#  'Rp81.400',
#  'Rp27.999',
#  'Rp22.000',
#  'Rp6.000',
#  'Rp9.500',
#  'Rp5.600']

# %%
# Penjual
seller = [penjual.text for penjual in soup.find_all("span", {"class":"T0rpy-LEwYNQifsgB-3SQw== pC8DMVkBZGW7-egObcWMFQ== flip"})]
seller
# Out:
# ['Wu Meyers Official Shop',
#  'Culametan Food',
#  'kylafood',
#  'Gerai Snack Official Shop',
#  'kylafood',
#  'gaiagarut',
#  'SuperSnacksShop',
#  'Endo Shop ID',
#  'snackmama_medan',
#  'PONCREA-Shop']

# %%
# City
city = [kota.text for kota in soup.find_all("span", {"class":"pC8DMVkBZGW7-egObcWMFQ== flip"})]
city
# Out:
# ['Surabaya',
#  'Kab. Garut',
#  'Bandung',
#  'Kab. Tangerang',
#  'Bandung',
#  'Kab. Garut',
#  'Kab. Bandung',
#  'Kab. Garut',
#  'Medan',
#  'Kab. Bandung Barat']

# %%
# Selling
selling = [terjual.text for terjual in soup.find_all("span", {"class":"se8WAnkjbVXZNA8mT+Veuw=="})]
selling
# Out:
# ['100+ terjual',
#  '750+ terjual',
#  '100+ terjual',
#  '18 terjual',
#  '80+ terjual',
#  '8 terjual',
#  '100+ terjual',
#  '60+ terjual',
#  '60+ terjual',
#  '40+ terjual',
#  '2 terjual']

# %%
# Rating
rating = [peringkat.text for peringkat in soup.find_all("span", {"class":"_9jWGz3C-GX7Myq-32zWG9w=="})]
rating
# Out:
# ['5.0', '4.9', '4.9', '5.0', '4.8', '5.0', '4.9', '5.0', '5.0', '5.0', '5.0']

# %%
# Url
# <a class="oQ94Awb6LlTiGByQZo8Lyw== IM26HEnTb-krJayD-R0OHw==" href="https://www.tokopedia.com/knads/seblak-instant-komplit-frozen?extParam=ivf%3Dfalse%26keyword%3Dseblak&amp;src=topads" data-theme="default"><div class="bYD8FcVCFyOBiVyITwDj1Q=="><div class="FsRHU-HdyqHfg3GrIQNUWA=="><div class="Het-JIVjmDQQceOwOkdz3A=="><div class="css-bqlp8e responsive EXUyQTyJzTrmf3n3cdbJjA=="><span class="responsive css-10rucli"></span><img class="css-1c345mg NWVIhquIvF0Jc0Qlizjluw==" decoding="async" src="https://images.tokopedia.net/img/cache/200-square/VqbcmM/2024/12/15/87597469-f092-4700-9b4d-c62d4d6d4dc9.jpg.webp?ect=4g" alt="product-image" crossorigin="anonymous"></div><div class="b+wqDn82Lb4v7GPQksrC8w=="><span class="GnvFY01xBCRPQXkPKtn0wg==">Ad</span></div></div></div><div class="WABnq4pXOYQihv0hUfQwOg== "><div class="_6+OpBPVGAgqnmycna+bWIw=="><span class="_0T8-iGxMpV6NEsYEhwkqEg==">Seblak Instant Komplit Frozen</span></div><div class="XvaCkHiisn2EZFq0THwVug=="><div class="_67d6E1xDKIzw+i2D2L0tjw== ">Rp20.000</div></div><div class="bi73OIBbtCeigSPpdXXfdw=="><div class="_0EVGaF6amgN+TL67nEZN5w=="><img alt="shop badge" class="YtXczlnkXDXQ59u3vhDxiA==" src="https://images.tokopedia.net/img/power_merchant_badge.png"></div><div class="Jh7geoVa-F3B5Hk8ORh2qw=="><span class="T0rpy-LEwYNQifsgB-3SQw== pC8DMVkBZGW7-egObcWMFQ== flip">Knads</span><span class="pC8DMVkBZGW7-egObcWMFQ== flip">Bekasi</span></div></div><div class="yzteLOpXrKpZ7ZBeyZOnqg=="><button class="VKiqod10PS48V8++d3QnGQ==" type="button"><img alt="three dots" class="_6rBeQgHMk3kWCCJ6cezqbQ==" src="https://assets.tokopedia.net/assets-tokopedia-lite/v2/zeus/kratos/ae78c469.svg"></button></div></div></div><div></div></a>
url = ["https://www.tokopedia.com/"+link["href"] for link in soup.find_all("a",{"class":"oQ94Awb6LlTiGByQZo8Lyw== IM26HEnTb-krJayD-R0OHw=="})]
url
# Out:
# ['https://www.tokopedia.com/https://www.tokopedia.com/kyfood/kylafood-seblak-rempah-autentik-isi-5pcs',
#  'https://www.tokopedia.com/https://www.tokopedia.com/kyfood/kylafood-seblak-karuhun',
#  'https://www.tokopedia.com/https://www.tokopedia.com/kyfood/kylafood-seblak-rempah-authentik',
#  'https://www.tokopedia.com/https://www.tokopedia.com/knads/seblak-instant-komplit-frozen?extParam=ivf%3Dfalse%26keyword%3Dseblak&src=topads',
#  'https://www.tokopedia.com/https://www.tokopedia.com/foodstocks/seblak-instan-premium-bangsatria?extParam=ivf%3Dfalse%26keyword%3Dseblak&src=topads',
#  'https://www.tokopedia.com/https://www.tokopedia.com/ismileusaid-2/seblak-instan-komplit-seblak-instan-murah?extParam=ivf%3Dfalse%26keyword%3Dseblak&src=topads',
#  'https://www.tokopedia.com/https://www.tokopedia.com/golden-cakery/kerupuk-seblak-rafael-viral-pedas-dj-1-4-kg-af7fb?extParam=ivf%3Dfalse%26keyword%3Dseblak&src=topads',
# ...

# %%
# Mengecek data
len(product_name), len(price), len(seller), len(city), len(selling), len(rating), len(url)
# Out:
# (13, 13, 10, 10, 11, 11, 124)

# %%
# Memastika seluruh input list
if not isinstance(product_name, list):product_name = []
if not isinstance(price, list):price = []
if not isinstance(seller, list):seller = []
if not isinstance(city, list):city = []
if not isinstance(selling, list):selling = []
if not isinstance(rating, list):rating = []
if not isinstance(url, list):url = []

# Cek panjang data
length = [len(product_name), len(price), len(seller), len(city), len(selling), len(rating), len(url)]

# Mencari minimum length
min_length = min(length)
product_name = product_name[:min_length]
price = price[:min_length]
seller = seller[:min_length]
city = city[:min_length]
selling = selling[:min_length]
rating = rating[:min_length]
url = url[:min_length]

# %%
# Create table
data_seblak = pd.DataFrame({"Nama Produk":product_name,
                            "Harga":price,
                            "Penjual":seller,
                            "Kota Penjual":city,
                            "Penjualan":selling,
                            "Rating":rating,
                            "URL":url
                            })
data_seblak
# Out:
#                                           Nama Produk             Harga  \
# 0                       Seblak Instant Komplit Frozen          Rp20.000
# 1                    Seblak Instan Premium Bangsatria          Rp21.000
# 2   Kerupuk Bawang Warna 5 Kg (BALL) Kerupuk Sebla...          Rp86.300
# 3   Kerupuk Seblak Rafael Pedas / Seblak Mawar Ped...          Rp16.000
# 4                                 seblak mantul rindu          Rp10.000
# ..                                                ...               ...
# 88                                   Gurilem Sangarrr          Rp13.000
# 89                               Batagor khas Bandung         Rp135.000
# 90                        seblak 100gr kerupuk seblak           Rp5.000
# 91  Cemilan 250GR Krupuk seblak kering Rafael peda...           Rp8.000
# 92                       Kylafood Seblak Kwetiaw play  Rp19.975Rp23.500
#
#                            Penjual     Kota Penjual     Penjualan Rating  \
# ...

# %%
print(len(product_name), len(price), len(seller), len(city), len(selling), len(rating), len(url))
# Out:
# 93 93 93 93 93 93 93

# %%
min_length = min(length)
product_name = product_name[:min_length]
price = price[:min_length]
seller = seller[:min_length]
city = city[:min_length]
selling = selling[:min_length]
rating = rating[:min_length]
url = url[:min_length]

# %%
print(len(product_name), len(price), len(seller), len(city), len(selling), len(rating), len(url))
# Out:
# 93 93 93 93 93 93 93

# %%
print("Lengths of lists:")
print("Product Name:", len(product_name))
print("Price:", len(price))
print("Seller:", len(seller))
print("City:", len(city))
print("Selling:", len(selling))
print("Rating:", len(rating))
print("URL:", len(url))
# Out:
# Lengths of lists:
# Product Name: 100
# Price: 100
# Seller: 100
# City: 100
# Selling: 88
# Rating: 86
# URL: 100

# %%
min_length = min(len(product_name), len(price), len(seller), len(city), len(selling), len(rating), len(url))
product_name = product_name[:min_length]
price = price[:min_length]
seller = seller[:min_length]
city = city[:min_length]
selling = selling[:min_length]
rating = rating[:min_length]
url = url[:min_length]

# %%
max_length = max(length)
product_name.extend([None] * (max_length - len(product_name)))
price.extend([None] * (max_length - len(price)))
seller.extend([None] * (max_length - len(seller)))
city.extend([None] * (max_length - len(city)))
selling.extend([None] * (max_length - len(selling)))
rating.extend([None] * (max_length - len(rating)))
url.extend([None] * (max_length - len(url)))

# %%
# Create list
product_name = []
price = []
seller = []
city = []
selling = []
rating = []
url = []

# Access multiple page
for page in range (1,11):
    page_url = f"https://www.tokopedia.com/search?navsource=&page={page}&q=seblak&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st="
    driver.get(page_url) # Manggil data
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    
    # Mengisi data dalam wadah
    product_name += [product.text for product in soup.find_all("span", {"class":"_0T8-iGxMpV6NEsYEhwkqEg=="})]
    price += [harga.text for harga in soup.find_all("div", {"class":"XvaCkHiisn2EZFq0THwVug=="})]
    seller += [penjual.text for penjual in soup.find_all("span", {"class":"T0rpy-LEwYNQifsgB-3SQw== pC8DMVkBZGW7-egObcWMFQ== flip"})]
    city += [kota.text for kota in soup.find_all("span", {"class":"pC8DMVkBZGW7-egObcWMFQ== flip"})]
    selling += [terjual.text for terjual in soup.find_all("span", {"class":"se8WAnkjbVXZNA8mT+Veuw=="})]
    rating += [peringkat.text for peringkat in soup.find_all("span", {"class":"_9jWGz3C-GX7Myq-32zWG9w=="})]
    url += ["https://www.tokopedia.com/"+link["href"] for link in soup.find_all("a",{"class":"oQ94Awb6LlTiGByQZo8Lyw== IM26HEnTb-krJayD-R0OHw=="})]

data_seblak = pd.DataFrame({"Nama Produk":product_name,
                            "Harga":price,
                            "Penjual":seller,
                            "Kota Penjual":city,
                            "Penjualan":selling,
                            "Rating":rating,
                            "URL":url
                            })
data_seblak
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 26
#      23     rating += [peringkat.text for peringkat in soup.find_all("span", {"class":"_9jWGz3C-GX7Myq-32zWG9w=="})]
#      24     url += ["https://www.tokopedia.com/"+link["href"] for link in soup.find_all("a",{"class":"oQ94Awb6LlTiGByQZo8Lyw== IM26HEnTb-krJayD-R0OHw=="})]
# ---> 26 data_seblak = pd.DataFrame({"Nama Produk":product_name,
#      27                             "Harga":price,
#      28                             "Penjual":seller,
#      29                             "Kota Penjual":city,
#      30                             "Penjualan":selling,
#      31                             "Rating":rating,
#      32                             "URL":url
#      33                             })
#      34 data_seblak
#
# ...

# %%
print(len(product_name), len(price), len(seller), len(city), len(selling), len(rating), len(url))
# Out:
# 100 100 100 100 88 86 100

# %% [markdown]
# Data Preparation

# %%
data_seblak.head()
# Out:
#                                          Nama Produk     Harga  \
# 0                      Seblak Instant Komplit Frozen  Rp20.000
# 1                   Seblak Instan Premium Bangsatria  Rp21.000
# 2  Kerupuk Bawang Warna 5 Kg (BALL) Kerupuk Sebla...  Rp86.300
# 3  Kerupuk Seblak Rafael Pedas / Seblak Mawar Ped...  Rp16.000
# 4                                seblak mantul rindu  Rp10.000
#
#                         Penjual     Kota Penjual     Penjualan Rating  \
# 0                         Knads           Bekasi   50+ terjual    5.0
# 1                    Foodstocks  Jakarta Selatan     6 terjual    5.0
# 2  Distributor Topping Baso Aci          Bandung  250+ terjual    4.9
# 3               DUO BOCIL SNACK            Depok     6 terjual    5.0
# 4                  ZalfaBarokah          Bandung  1rb+ terjual    5.0
#
#                                                  URL
# 0  https://www.tokopedia.com/https://www.tokopedi...
# 1  https://www.tokopedia.com/https://www.tokopedi...
# ...

# %%
data_seblak.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Nama Produk   93 non-null     object
#  1   Harga         93 non-null     object
#  2   Penjual       93 non-null     object
#  3   Kota Penjual  93 non-null     object
#  4   Penjualan     93 non-null     object
#  5   Rating        93 non-null     object
#  6   URL           93 non-null     object
# dtypes: object(7)
# memory usage: 5.2+ KB
